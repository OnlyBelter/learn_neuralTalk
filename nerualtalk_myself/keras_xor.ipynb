# %% [markdown]
# ## 用keras实现异或(XOR)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
import numpy as np

# %% [markdown]
# 设置每次训练使用的样本数(batch size)， 分类的数量(number of class)，以及训练的次数(epoch)

# %%
batch_size = 1
num_classes = 1
epochs = 1000

# %% [markdown]
# 训练数据&测试数据

# %%
x_train = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
x_test = np.array([[0, 0], [1, 0]])
y_train = np.array([[0], [1], [1], [0]])
y_test = np.array([[0], [1]])

# %%
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 4 train samples
# 2 test samples

# %% [markdown]
# 定义一个序贯模型

# %%
model = Sequential()

# %% [markdown]
# 下面添加一个全连接层，输入层有2个特征，后面的隐藏层有2个单元，且隐藏层的激活函数为tanh
# 所有层的bias都是自动添加的

# %%
model.add(Dense(2, activation='tanh', input_shape=(2,)))

# %% [markdown]
# 最后的输出也是一个全连接层，激活函数为sigmoid

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 3
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 选择随机梯度下降方法(SGD)训练网络，设置学习率

# %%
sgd = SGD(lr=0.8)

# %% [markdown]
# 编译模型，使用二分类的交叉熵(binary_crossentropy)作为代价函数

# %%
model.compile(loss='binary_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

# %% [markdown]
# 训练模型，包含了前向传播、求参数的梯度和反向传播
# 使用验证数据进行验证

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Train on 4 samples, validate on 2 samples
# Epoch 1/1000
# 4/4 [==============================] - 0s - loss: 0.7762 - acc: 0.5000 - val_loss: 0.6970 - val_acc: 0.5000
# Epoch 2/1000
# 4/4 [==============================] - 0s - loss: 0.8036 - acc: 0.5000 - val_loss: 0.6935 - val_acc: 0.5000
# Epoch 3/1000
# 4/4 [==============================] - 0s - loss: 0.7796 - acc: 0.2500 - val_loss: 0.7028 - val_acc: 0.5000
# Epoch 4/1000
# 4/4 [==============================] - 0s - loss: 0.7773 - acc: 0.5000 - val_loss: 0.6954 - val_acc: 0.5000
# Epoch 5/1000
# 4/4 [==============================] - 0s - loss: 0.8033 - acc: 0.2500 - val_loss: 0.6940 - val_acc: 0.5000
# Epoch 6/1000
# 4/4 [==============================] - 0s - loss: 0.7766 - acc: 0.5000 - val_loss: 0.6991 - val_acc: 0.5000
# Epoch 7/1000
# 4/4 [==============================] - 0s - loss: 0.8079 - acc: 0.2500 - val_loss: 0.6937 - val_acc: 0.5000
# Epoch 8/1000
# ...

# %% [markdown]
# 查看结果

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print(model.predict_proba(x_train))
# Out:
# Test loss: 0.693506360054
# Test accuracy: 0.5
# 4/4 [==============================] - 0s
# [[ 0.51339847]
#  [ 0.51339847]
#  [ 0.51339847]
#  [ 0.51339847]]
